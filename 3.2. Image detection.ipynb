# %% [markdown]
# ### Object detection

# %%
# !pip install ultralytics (Don't forget to install it)

import cv2
import time
import numpy as np
from ultralytics import YOLO

# %%
# Load the YOLOv11 model for segmentation (or make sure to download 'yolo11n-seg.pt')
# You can check https://docs.ultralytics.com/tasks/segment/ for other models

model = YOLO("yolo11n-seg")

# Define the video source (Can be the path or camera index)
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1920)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 1080)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Measure processing time to calculate latency
    start_time = time.time()
    
    # Perform detection on the frame 
    results = model(
        frame, 
        conf=0.7,  # Confidence threshold: show detections over 70%
        classes=[0]  # "0" to focus only on people
        )
    latency = (time.time() - start_time) * 1000  # milliseconds of latency

    # Access bounding boxes
    boxes_obj = results[0].boxes
    if boxes_obj is not None and len(boxes_obj) > 0:
        bboxes = boxes_obj.xyxy.cpu().numpy()   # [x1, y1, x2, y2]
        confs = boxes_obj.conf.cpu().numpy()    # Confidence scores
        classes = boxes_obj.cls.cpu().numpy()   # Class indices
        
        for i, box in enumerate(bboxes):
            x1, y1, x2, y2 = map(int, box)
            
            # Get the class name if available
            class_name = model.names[int(classes[i])] if hasattr(model, 'names') else str(int(classes[i]))
            label = f'{class_name} {confs[i]:.2f}'
            # Draw bounding box and label on the frame
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 2)
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

    # Process segmentations: assign a random color to each detected mask
    masks_obj = results[0].masks
    if masks_obj is not None and len(masks_obj) > 0:
        # Extract masks; assumes masks_obj.data is a tensor
        masks = masks_obj.data.cpu().numpy() if hasattr(masks_obj.data, 'cpu') else masks_obj.data
        for mask in masks:
            # Convert the mask to binary (threshold 0.5) and scale to 0–255
            mask_bin = (mask > 0.5).astype(np.uint8) * 255
            # Resize the mask to match the frame size
            mask_bin = cv2.resize(mask_bin, (frame.shape[1], frame.shape[0]), interpolation=cv2.INTER_NEAREST)
            
            # Create a 3-channel boolean mask
            binary_mask = cv2.threshold(mask_bin, 127, 255, cv2.THRESH_BINARY)[1]
            binary_mask_3c = cv2.merge([binary_mask, binary_mask, binary_mask])
            
            # Generate a random color (BGR)
            random_color = np.random.randint(0, 256, size=(3,), dtype=np.uint8)
            # Create a color mask image same size as frame
            colored_mask = np.full((frame.shape[0], frame.shape[1], 3), random_color, dtype=np.uint8)
            
            # Combine mask with the frame: in regions where mask is 255, use the random color
            output_frame = frame.copy()
            output_frame[binary_mask_3c == 255] = colored_mask[binary_mask_3c == 255]
            
            # Update the frame with the colored mask (preserve the natural background)
            frame = output_frame
        
        # Display the number of detected masks
        cv2.putText(frame, f'Masks: {len(masks)}', (10, 70),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
    
    # Display the latency on the frame
    cv2.putText(frame, f'Latency: {latency:.1f}ms', (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 0), 2)

    # Show the processed frame in real-time
    cv2.imshow("YOLOv11-Seg - Real-time Segmentation", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 person, 289.2ms
# Speed: 11.1ms preprocess, 289.2ms inference, 22.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 186.8ms
# Speed: 4.7ms preprocess, 186.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 130.7ms
# Speed: 2.3ms preprocess, 130.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 107.4ms
# Speed: 2.4ms preprocess, 107.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.3ms
# Speed: 2.4ms preprocess, 104.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 113.7ms
# Speed: 2.3ms preprocess, 113.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 113.6ms
# Speed: 2.5ms preprocess, 113.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 112.3ms
# Speed: 1.9ms preprocess, 112.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 118.5ms
# Speed: 5.2ms preprocess, 118.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 107.6ms
# Speed: 3.6ms preprocess, 107.6ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 117.2ms
# Speed: 3.0ms preprocess, 117.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.9ms
# Speed: 3.4ms preprocess, 98.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 119.1ms
# Speed: 2.7ms preprocess, 119.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 129.5ms
# Speed: 3.2ms preprocess, 129.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 131.2ms
# Speed: 3.7ms preprocess, 131.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 136.0ms
# Speed: 5.6ms preprocess, 136.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 118.5ms
# Speed: 6.5ms preprocess, 118.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 101.9ms
# Speed: 2.2ms preprocess, 101.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 121.4ms
# Speed: 2.0ms preprocess, 121.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 114.2ms
# Speed: 8.7ms preprocess, 114.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 102.5ms
# Speed: 2.4ms preprocess, 102.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 133.7ms
# Speed: 1.9ms preprocess, 133.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 171.8ms
# Speed: 1.9ms preprocess, 171.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 96.7ms
# Speed: 3.1ms preprocess, 96.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 112.3ms
# Speed: 1.6ms preprocess, 112.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.7ms
# Speed: 2.2ms preprocess, 90.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 96.1ms
# Speed: 1.6ms preprocess, 96.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 109.3ms
# Speed: 1.6ms preprocess, 109.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.4ms
# Speed: 1.9ms preprocess, 99.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.8ms
# Speed: 1.7ms preprocess, 99.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 91.8ms
# Speed: 1.8ms preprocess, 91.8ms inference, 15.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 94.1ms
# Speed: 2.3ms preprocess, 94.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 85.9ms
# Speed: 2.1ms preprocess, 85.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.2ms
# Speed: 1.9ms preprocess, 88.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 83.8ms
# Speed: 2.8ms preprocess, 83.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.6ms
# Speed: 3.1ms preprocess, 84.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.7ms
# Speed: 1.7ms preprocess, 87.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 87.1ms
# Speed: 1.9ms preprocess, 87.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 94.5ms
# Speed: 4.6ms preprocess, 94.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.4ms
# Speed: 2.2ms preprocess, 90.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.7ms
# Speed: 1.8ms preprocess, 89.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.3ms
# Speed: 2.4ms preprocess, 90.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 101.1ms
# Speed: 2.0ms preprocess, 101.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.6ms
# Speed: 2.0ms preprocess, 85.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.0ms
# Speed: 1.7ms preprocess, 90.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 91.4ms
# Speed: 2.3ms preprocess, 91.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.3ms
# Speed: 1.9ms preprocess, 85.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.8ms
# Speed: 3.1ms preprocess, 89.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.6ms
# Speed: 1.6ms preprocess, 89.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.8ms
# Speed: 1.8ms preprocess, 90.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 124.8ms
# Speed: 2.4ms preprocess, 124.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.0ms
# Speed: 3.0ms preprocess, 90.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.7ms
# Speed: 1.8ms preprocess, 90.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.9ms
# Speed: 2.0ms preprocess, 88.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.7ms
# Speed: 2.0ms preprocess, 88.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.7ms
# Speed: 2.2ms preprocess, 87.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 92.2ms
# Speed: 2.9ms preprocess, 92.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.7ms
# Speed: 1.9ms preprocess, 90.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.4ms
# Speed: 3.0ms preprocess, 89.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.0ms
# Speed: 2.9ms preprocess, 85.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.5ms
# Speed: 1.8ms preprocess, 88.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.7ms
# Speed: 2.4ms preprocess, 99.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 95.4ms
# Speed: 1.7ms preprocess, 95.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 81.7ms
# Speed: 2.9ms preprocess, 81.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.8ms
# Speed: 1.7ms preprocess, 89.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 88.1ms
# Speed: 2.1ms preprocess, 88.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 83.2ms
# Speed: 2.0ms preprocess, 83.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.5ms
# Speed: 1.6ms preprocess, 84.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 85.6ms
# Speed: 1.9ms preprocess, 85.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.2ms
# Speed: 2.8ms preprocess, 84.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 90.4ms
# Speed: 2.5ms preprocess, 90.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.3ms
# Speed: 3.0ms preprocess, 84.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 83.9ms
# Speed: 2.1ms preprocess, 83.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 78.9ms
# Speed: 2.4ms preprocess, 78.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 91.6ms
# Speed: 1.8ms preprocess, 91.6ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 114.4ms
# Speed: 1.9ms preprocess, 114.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 89.8ms
# Speed: 3.3ms preprocess, 89.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 85.1ms
# Speed: 1.7ms preprocess, 85.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 84.0ms
# Speed: 3.0ms preprocess, 84.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 84.1ms
# Speed: 1.7ms preprocess, 84.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 87.9ms
# Speed: 1.7ms preprocess, 87.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 80.7ms
# Speed: 1.8ms preprocess, 80.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 89.4ms
# Speed: 1.9ms preprocess, 89.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 81.0ms
# Speed: 2.6ms preprocess, 81.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 82.6ms
# Speed: 1.8ms preprocess, 82.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 81.2ms
# Speed: 2.0ms preprocess, 81.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 82.7ms
# Speed: 3.0ms preprocess, 82.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 81.1ms
# Speed: 4.5ms preprocess, 81.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 80.9ms
# Speed: 1.7ms preprocess, 80.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 85.0ms
# Speed: 1.7ms preprocess, 85.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 80.5ms
# Speed: 2.0ms preprocess, 80.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 86.7ms
# Speed: 1.8ms preprocess, 86.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 82.8ms
# Speed: 1.6ms preprocess, 82.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 95.6ms
# Speed: 6.4ms preprocess, 95.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 94.6ms
# Speed: 1.8ms preprocess, 94.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.8ms
# Speed: 1.7ms preprocess, 102.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 85.4ms
# Speed: 1.7ms preprocess, 85.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.9ms
# Speed: 2.0ms preprocess, 97.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 113.9ms
# Speed: 1.8ms preprocess, 113.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 118.7ms
# Speed: 2.1ms preprocess, 118.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 83.8ms
# Speed: 1.8ms preprocess, 83.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 89.5ms
# Speed: 1.7ms preprocess, 89.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 81.2ms
# Speed: 2.2ms preprocess, 81.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.9ms
# Speed: 3.3ms preprocess, 79.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 86.7ms
# Speed: 2.0ms preprocess, 86.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 88.8ms
# Speed: 1.9ms preprocess, 88.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 83.4ms
# Speed: 1.6ms preprocess, 83.4ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 95.1ms
# Speed: 2.2ms preprocess, 95.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 85.1ms
# Speed: 2.5ms preprocess, 85.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 84.8ms
# Speed: 2.1ms preprocess, 84.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 83.3ms
# Speed: 2.5ms preprocess, 83.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 84.9ms
# Speed: 2.1ms preprocess, 84.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 86.0ms
# Speed: 1.7ms preprocess, 86.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 82.2ms
# Speed: 2.0ms preprocess, 82.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 86.1ms
# Speed: 2.1ms preprocess, 86.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 91.1ms
# Speed: 1.8ms preprocess, 91.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 85.5ms
# Speed: 1.8ms preprocess, 85.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 84.0ms
# Speed: 1.8ms preprocess, 84.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 85.5ms
# Speed: 1.7ms preprocess, 85.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 84.8ms
# Speed: 2.9ms preprocess, 84.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 89.6ms
# Speed: 2.1ms preprocess, 89.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 93.0ms
# Speed: 1.8ms preprocess, 93.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 112.6ms
# Speed: 1.9ms preprocess, 112.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.1ms
# Speed: 1.8ms preprocess, 104.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 92.8ms
# Speed: 2.1ms preprocess, 92.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.0ms
# Speed: 2.0ms preprocess, 99.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.7ms
# Speed: 2.0ms preprocess, 106.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.8ms
# Speed: 2.0ms preprocess, 104.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 113.3ms
# Speed: 2.2ms preprocess, 113.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 122.3ms
# Speed: 2.4ms preprocess, 122.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 135.8ms
# Speed: 3.1ms preprocess, 135.8ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 116.0ms
# Speed: 3.0ms preprocess, 116.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.6ms
# Speed: 2.4ms preprocess, 106.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.4ms
# Speed: 2.1ms preprocess, 100.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.5ms
# Speed: 2.6ms preprocess, 103.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 115.1ms
# Speed: 1.9ms preprocess, 115.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.7ms
# Speed: 2.5ms preprocess, 105.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.0ms
# Speed: 2.0ms preprocess, 98.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.1ms
# Speed: 2.1ms preprocess, 105.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 101.9ms
# Speed: 2.1ms preprocess, 101.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 118.4ms
# Speed: 3.6ms preprocess, 118.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 111.7ms
# Speed: 2.6ms preprocess, 111.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 110.9ms
# Speed: 2.8ms preprocess, 110.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.7ms
# Speed: 2.0ms preprocess, 96.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 118.5ms
# Speed: 2.1ms preprocess, 118.5ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 137.9ms
# Speed: 2.3ms preprocess, 137.9ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.2ms
# Speed: 2.7ms preprocess, 103.2ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 109.8ms
# Speed: 3.2ms preprocess, 109.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.2ms
# Speed: 5.4ms preprocess, 106.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.7ms
# Speed: 2.1ms preprocess, 101.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 93.8ms
# Speed: 3.0ms preprocess, 93.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.4ms
# Speed: 2.4ms preprocess, 102.4ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.1ms
# Speed: 3.5ms preprocess, 101.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.7ms
# Speed: 2.1ms preprocess, 96.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.6ms
# Speed: 2.1ms preprocess, 100.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.2ms
# Speed: 3.0ms preprocess, 98.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 116.9ms
# Speed: 3.2ms preprocess, 116.9ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.2ms
# Speed: 2.4ms preprocess, 104.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 92.1ms
# Speed: 3.2ms preprocess, 92.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.1ms
# Speed: 2.1ms preprocess, 97.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 95.7ms
# Speed: 2.7ms preprocess, 95.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.3ms
# Speed: 2.2ms preprocess, 103.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.1ms
# Speed: 2.4ms preprocess, 100.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.4ms
# Speed: 2.2ms preprocess, 98.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 107.3ms
# Speed: 2.5ms preprocess, 107.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.8ms
# Speed: 2.2ms preprocess, 99.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 115.3ms
# Speed: 2.3ms preprocess, 115.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 137.6ms
# Speed: 2.6ms preprocess, 137.6ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 137.2ms
# Speed: 2.3ms preprocess, 137.2ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 120.2ms
# Speed: 3.6ms preprocess, 120.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.4ms
# Speed: 2.6ms preprocess, 103.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 95.3ms
# Speed: 2.0ms preprocess, 95.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.0ms
# Speed: 3.0ms preprocess, 101.0ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.6ms
# Speed: 2.2ms preprocess, 105.6ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.7ms
# Speed: 2.5ms preprocess, 105.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.4ms
# Speed: 2.8ms preprocess, 97.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.4ms
# Speed: 2.2ms preprocess, 102.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.0ms
# Speed: 2.1ms preprocess, 102.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.5ms
# Speed: 2.7ms preprocess, 96.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 110.8ms
# Speed: 2.5ms preprocess, 110.8ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 113.5ms
# Speed: 3.7ms preprocess, 113.5ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 134.9ms
# Speed: 4.5ms preprocess, 134.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.7ms
# Speed: 2.2ms preprocess, 102.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.1ms
# Speed: 2.1ms preprocess, 97.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 107.0ms
# Speed: 2.4ms preprocess, 107.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 94.4ms
# Speed: 3.7ms preprocess, 94.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.2ms
# Speed: 2.4ms preprocess, 102.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.4ms
# Speed: 2.1ms preprocess, 97.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 142.9ms
# Speed: 2.5ms preprocess, 142.9ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 121.7ms
# Speed: 2.3ms preprocess, 121.7ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 116.6ms
# Speed: 2.7ms preprocess, 116.6ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 112.5ms
# Speed: 2.1ms preprocess, 112.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.6ms
# Speed: 2.5ms preprocess, 104.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 107.6ms
# Speed: 2.4ms preprocess, 107.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 112.3ms
# Speed: 2.0ms preprocess, 112.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 120.0ms
# Speed: 2.1ms preprocess, 120.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 108.6ms
# Speed: 2.5ms preprocess, 108.6ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 108.2ms
# Speed: 2.4ms preprocess, 108.2ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 159.6ms
# Speed: 3.6ms preprocess, 159.6ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 159.2ms
# Speed: 3.7ms preprocess, 159.2ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 114.8ms
# Speed: 2.7ms preprocess, 114.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 114.6ms
# Speed: 2.1ms preprocess, 114.6ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 111.1ms
# Speed: 2.8ms preprocess, 111.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 107.1ms
# Speed: 1.9ms preprocess, 107.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 113.5ms
# Speed: 3.2ms preprocess, 113.5ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 108.6ms
# Speed: 2.0ms preprocess, 108.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 125.5ms
# Speed: 2.4ms preprocess, 125.5ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 126.7ms
# Speed: 2.9ms preprocess, 126.7ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 128.7ms
# Speed: 2.3ms preprocess, 128.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.2ms
# Speed: 4.3ms preprocess, 106.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 110.4ms
# Speed: 2.1ms preprocess, 110.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ### Video Detection

# %%
video_path = "Video Useful/people-detection.mp4"

# %%
output_path = "Save Images & Videos/output_video.avi"

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# %% [markdown]
# Use https://www.photopea.com/ for determine distintive points, take a frame of the image, usign the rule on the program, We can determine where put line on.

# %%
# To know whether the person in the video crosses the determined digital limit or not

def signed_distance(point, line):
    """
    Calculates the signed distance from a point to a line defined by two points.
    Allows us to determine on which side of the line the point lies.
    point: (x, y)
    line: ((x1, y1), (x2, y2))
    """
    x, y = point
    (x1, y1), (x2, y2) = line
    num = (y2 - y1) * x - (x2 - x1) * y + x2 * y1 - y2 * x1
    den = np.sqrt((y2 - y1) ** 2 + (x2 - x1) ** 2)
    return num / den if den != 0 else 0

# Define counting lines
line1 = ((130, 120), (15, 250))  # ((130, 180), (25, 300)) 
line2 = ((650, 175), (720, 275))

# Counters for each line
count_line1 = 0
count_line2 = 0

# Threshold to associate detections between frames
distance_threshold = 25 #50

# List to store centroids from the previous frame
prev_centroids = []

# Load YOLO model (assumes "person" is class 0 in COCO)
model = YOLO("yolo11n.pt")

# Open input video and configure VideoWriter for output video
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    raise ValueError("Could not open input video.")

fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*'XVID') # "XVID because is light format"
writer = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Detection with YOLOv11
    results = model(frame, conf=0.7)
    # Access the first result from the list
    boxes_obj = results[0].boxes

    current_centroids = []
    if boxes_obj is not None and len(boxes_obj) > 0:
        # Extract bounding boxes and classes as NumPy arrays
        bboxes = boxes_obj.xyxy.cpu().numpy()  # Array of shape (N,4)
        classes = boxes_obj.cls.cpu().numpy()  # Array of shape (N,)
        # Filter detections of "person" by checking that the class is 0
        for i in range(len(bboxes)):
            if int(classes[i]) == 0:
                x1, y1, x2, y2 = map(int, bboxes[i])
                centroid = ((x1 + x2) // 2, (y1 + y2) // 2)
                current_centroids.append(centroid)
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.circle(frame, centroid, 4, (0, 255, 0), -1)

    # Draw the counting lines
    cv2.line(frame, line1[0], line1[1], (255, 0, 0), 2)
    cv2.line(frame, line2[0], line2[1], (0, 0, 255), 2)

    # Compare each current centroid with those from the previous frame to detect crossings
    for curr in current_centroids:
        best_distance = float('inf')
        best_prev = None
        for prev in prev_centroids:
            d = np.linalg.norm(np.array(curr) - np.array(prev))
            if d < best_distance and d < distance_threshold:
                best_distance = d
                best_prev = prev
        if best_prev is not None:
            # Check crossing of line 1
            prev_side1 = signed_distance(best_prev, line1)
            curr_side1 = signed_distance(curr, line1)
            if prev_side1 * curr_side1 < 0:
                count_line1 += 1
            # Check crossing of line 2
            prev_side2 = signed_distance(best_prev, line2)
            curr_side2 = signed_distance(curr, line2)
            if prev_side2 * curr_side2 < 0:
                count_line2 += 1

    # Draw the counters on the frame
    cv2.putText(frame, f"Clothes Section: {count_line1}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
    cv2.putText(frame, f"Sport Section: {count_line2}", (10, 70),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    # Write the processed frame to the output video
    writer.write(frame)

    # Update previous frame centroids
    prev_centroids = current_centroids.copy()

cap.release()
writer.release()
print(f"Video processed and saved to: {output_path}")
# Out:
# 0: 384x640 (no detections), 115.1ms
# Speed: 6.8ms preprocess, 115.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.7ms
# Speed: 2.5ms preprocess, 79.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.7ms
# Speed: 2.3ms preprocess, 69.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 83.9ms
# Speed: 2.3ms preprocess, 83.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 143.7ms
# Speed: 2.4ms preprocess, 143.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.2ms
# Speed: 2.9ms preprocess, 78.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.5ms
# Speed: 2.3ms preprocess, 89.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 86.2ms
# Speed: 3.7ms preprocess, 86.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 168.2ms
# Speed: 2.7ms preprocess, 168.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 123.2ms
# Speed: 3.3ms preprocess, 123.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 132.6ms
# Speed: 3.1ms preprocess, 132.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 142.5ms
# Speed: 12.9ms preprocess, 142.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.0ms
# Speed: 4.9ms preprocess, 82.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 97.6ms
# Speed: 2.7ms preprocess, 97.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 101.9ms
# Speed: 3.2ms preprocess, 101.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 119.2ms
# Speed: 4.5ms preprocess, 119.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.8ms
# Speed: 3.6ms preprocess, 98.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 93.5ms
# Speed: 2.3ms preprocess, 93.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 77.3ms
# Speed: 2.8ms preprocess, 77.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.5ms
# Speed: 1.9ms preprocess, 65.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 60.0ms
# Speed: 2.1ms preprocess, 60.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 65.4ms
# Speed: 1.9ms preprocess, 65.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.3ms
# Speed: 2.0ms preprocess, 63.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.4ms
# Speed: 2.2ms preprocess, 73.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 94.4ms
# Speed: 2.0ms preprocess, 94.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 108.9ms
# Speed: 4.3ms preprocess, 108.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 115.2ms
# Speed: 2.6ms preprocess, 115.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 86.3ms
# Speed: 3.6ms preprocess, 86.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 182.8ms
# Speed: 3.1ms preprocess, 182.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 83.1ms
# Speed: 2.1ms preprocess, 83.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 75.3ms
# Speed: 2.1ms preprocess, 75.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.5ms
# Speed: 2.7ms preprocess, 70.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.9ms
# Speed: 2.2ms preprocess, 73.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.4ms
# Speed: 2.9ms preprocess, 63.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.6ms
# Speed: 2.0ms preprocess, 63.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 66.9ms
# Speed: 3.1ms preprocess, 66.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 65.1ms
# Speed: 2.1ms preprocess, 65.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.3ms
# Speed: 4.4ms preprocess, 79.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 95.2ms
# Speed: 2.6ms preprocess, 95.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.0ms
# Speed: 2.3ms preprocess, 70.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 65.1ms
# Speed: 2.0ms preprocess, 65.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.2ms
# Speed: 1.9ms preprocess, 66.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 66.9ms
# Speed: 1.9ms preprocess, 66.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 89.1ms
# Speed: 2.8ms preprocess, 89.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 86.3ms
# Speed: 3.3ms preprocess, 86.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.7ms
# Speed: 2.4ms preprocess, 72.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 86.1ms
# Speed: 2.5ms preprocess, 86.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 137.3ms
# Speed: 2.6ms preprocess, 137.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 123.9ms
# Speed: 3.4ms preprocess, 123.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 214.3ms
# Speed: 3.5ms preprocess, 214.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 233.0ms
# Speed: 5.2ms preprocess, 233.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 150.8ms
# Speed: 2.8ms preprocess, 150.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 265.6ms
# Speed: 2.9ms preprocess, 265.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 268.9ms
# Speed: 19.2ms preprocess, 268.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 227.6ms
# Speed: 10.3ms preprocess, 227.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 246.5ms
# Speed: 6.6ms preprocess, 246.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 280.1ms
# Speed: 4.4ms preprocess, 280.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 180.0ms
# Speed: 10.0ms preprocess, 180.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 185.4ms
# Speed: 4.5ms preprocess, 185.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 313.8ms
# Speed: 5.1ms preprocess, 313.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 187.3ms
# Speed: 14.2ms preprocess, 187.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 199.8ms
# Speed: 4.2ms preprocess, 199.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 244.1ms
# Speed: 4.4ms preprocess, 244.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 205.8ms
# Speed: 31.7ms preprocess, 205.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 184.7ms
# Speed: 5.5ms preprocess, 184.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 177.4ms
# Speed: 4.1ms preprocess, 177.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 166.5ms
# Speed: 4.9ms preprocess, 166.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.8ms
# Speed: 5.3ms preprocess, 168.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 176.4ms
# Speed: 3.2ms preprocess, 176.4ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 190.0ms
# Speed: 2.7ms preprocess, 190.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 202.8ms
# Speed: 9.3ms preprocess, 202.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 160.5ms
# Speed: 3.2ms preprocess, 160.5ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 207.8ms
# Speed: 5.7ms preprocess, 207.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 194.3ms
# Speed: 5.8ms preprocess, 194.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 174.3ms
# Speed: 10.5ms preprocess, 174.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 152.2ms
# Speed: 5.3ms preprocess, 152.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 281.1ms
# Speed: 5.6ms preprocess, 281.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.0ms
# Speed: 5.5ms preprocess, 154.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 164.6ms
# Speed: 10.6ms preprocess, 164.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 212.3ms
# Speed: 3.5ms preprocess, 212.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.7ms
# Speed: 6.0ms preprocess, 157.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.9ms
# Speed: 7.4ms preprocess, 157.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 161.7ms
# Speed: 5.4ms preprocess, 161.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 168.0ms
# Speed: 5.6ms preprocess, 168.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 168.0ms
# Speed: 9.2ms preprocess, 168.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 168.4ms
# Speed: 3.5ms preprocess, 168.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 159.5ms
# Speed: 6.3ms preprocess, 159.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 184.7ms
# Speed: 9.1ms preprocess, 184.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 184.1ms
# Speed: 6.2ms preprocess, 184.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.8ms
# Speed: 9.5ms preprocess, 155.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 163.4ms
# Speed: 6.5ms preprocess, 163.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 159.6ms
# Speed: 4.0ms preprocess, 159.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 184.1ms
# Speed: 7.3ms preprocess, 184.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 177.1ms
# Speed: 5.1ms preprocess, 177.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 163.4ms
# Speed: 6.8ms preprocess, 163.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 163.1ms
# Speed: 8.4ms preprocess, 163.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 174.3ms
# Speed: 5.0ms preprocess, 174.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 169.7ms
# Speed: 5.8ms preprocess, 169.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 183.4ms
# Speed: 5.6ms preprocess, 183.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 169.8ms
# Speed: 8.4ms preprocess, 169.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 175.4ms
# Speed: 5.9ms preprocess, 175.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 273.0ms
# Speed: 14.3ms preprocess, 273.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.8ms
# Speed: 5.4ms preprocess, 151.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 165.7ms
# Speed: 6.1ms preprocess, 165.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 277.1ms
# Speed: 4.8ms preprocess, 277.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 178.1ms
# Speed: 5.7ms preprocess, 178.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.4ms
# Speed: 7.7ms preprocess, 157.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.1ms
# Speed: 5.0ms preprocess, 157.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 176.6ms
# Speed: 9.2ms preprocess, 176.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 161.0ms
# Speed: 4.2ms preprocess, 161.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 156.9ms
# Speed: 3.4ms preprocess, 156.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 186.0ms
# Speed: 5.5ms preprocess, 186.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 181.1ms
# Speed: 4.5ms preprocess, 181.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 188.8ms
# Speed: 4.6ms preprocess, 188.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.6ms
# Speed: 6.5ms preprocess, 149.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 160.0ms
# Speed: 5.9ms preprocess, 160.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 173.9ms
# Speed: 6.2ms preprocess, 173.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 188.1ms
# Speed: 5.0ms preprocess, 188.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 188.6ms
# Speed: 7.6ms preprocess, 188.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 194.9ms
# Speed: 3.2ms preprocess, 194.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 185.1ms
# Speed: 7.9ms preprocess, 185.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 179.0ms
# Speed: 4.5ms preprocess, 179.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 174.2ms
# Speed: 3.8ms preprocess, 174.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 173.0ms
# Speed: 4.5ms preprocess, 173.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 199.9ms
# Speed: 3.5ms preprocess, 199.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 168.2ms
# Speed: 12.0ms preprocess, 168.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 286.0ms
# Speed: 7.4ms preprocess, 286.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 169.2ms
# Speed: 7.2ms preprocess, 169.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 171.9ms
# Speed: 7.1ms preprocess, 171.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 176.7ms
# Speed: 4.9ms preprocess, 176.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 175.6ms
# Speed: 5.4ms preprocess, 175.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 170.8ms
# Speed: 5.3ms preprocess, 170.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 169.2ms
# Speed: 6.0ms preprocess, 169.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 171.5ms
# Speed: 9.7ms preprocess, 171.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 174.7ms
# Speed: 10.8ms preprocess, 174.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 169.6ms
# Speed: 5.5ms preprocess, 169.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 168.0ms
# Speed: 6.9ms preprocess, 168.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 167.6ms
# Speed: 4.5ms preprocess, 167.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 183.6ms
# Speed: 4.8ms preprocess, 183.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 188.1ms
# Speed: 8.1ms preprocess, 188.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.4ms
# Speed: 7.7ms preprocess, 153.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 158.9ms
# Speed: 4.1ms preprocess, 158.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.6ms
# Speed: 9.2ms preprocess, 151.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 164.1ms
# Speed: 6.8ms preprocess, 164.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 180.5ms
# Speed: 5.4ms preprocess, 180.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 176.2ms
# Speed: 4.5ms preprocess, 176.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 167.5ms
# Speed: 4.9ms preprocess, 167.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 174.0ms
# Speed: 5.2ms preprocess, 174.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 182.9ms
# Speed: 7.8ms preprocess, 182.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 169.5ms
# Speed: 4.9ms preprocess, 169.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 165.7ms
# Speed: 5.3ms preprocess, 165.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 272.8ms
# Speed: 5.3ms preprocess, 272.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 180.5ms
# Speed: 4.5ms preprocess, 180.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 184.2ms
# Speed: 4.0ms preprocess, 184.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.7ms
# Speed: 4.5ms preprocess, 154.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.8ms
# Speed: 7.0ms preprocess, 153.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 167.0ms
# Speed: 6.7ms preprocess, 167.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 184.0ms
# Speed: 5.2ms preprocess, 184.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 188.3ms
# Speed: 9.1ms preprocess, 188.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 192.2ms
# Speed: 8.4ms preprocess, 192.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 170.3ms
# Speed: 10.0ms preprocess, 170.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.5ms
# Speed: 4.8ms preprocess, 151.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 177.9ms
# Speed: 5.2ms preprocess, 177.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 190.4ms
# Speed: 6.3ms preprocess, 190.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 163.9ms
# Speed: 10.2ms preprocess, 163.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 172.3ms
# Speed: 6.2ms preprocess, 172.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 167.1ms
# Speed: 6.8ms preprocess, 167.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 196.0ms
# Speed: 7.1ms preprocess, 196.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.0ms
# Speed: 17.9ms preprocess, 157.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 156.9ms
# Speed: 8.7ms preprocess, 156.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 156.9ms
# Speed: 5.6ms preprocess, 156.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 191.5ms
# Speed: 5.9ms preprocess, 191.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 175.2ms
# Speed: 4.1ms preprocess, 175.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.9ms
# Speed: 5.6ms preprocess, 147.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.1ms
# Speed: 5.9ms preprocess, 154.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 166.2ms
# Speed: 5.2ms preprocess, 166.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 291.4ms
# Speed: 7.3ms preprocess, 291.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 150.4ms
# Speed: 6.4ms preprocess, 150.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 185.5ms
# Speed: 7.4ms preprocess, 185.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 192.3ms
# Speed: 4.1ms preprocess, 192.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.9ms
# Speed: 6.5ms preprocess, 159.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 149.4ms
# Speed: 4.1ms preprocess, 149.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 152.6ms
# Speed: 3.7ms preprocess, 152.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 147.0ms
# Speed: 6.4ms preprocess, 147.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 150.6ms
# Speed: 4.2ms preprocess, 150.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 151.9ms
# Speed: 4.4ms preprocess, 151.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 152.8ms
# Speed: 6.5ms preprocess, 152.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 155.2ms
# Speed: 7.9ms preprocess, 155.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 147.7ms
# Speed: 6.9ms preprocess, 147.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 162.9ms
# Speed: 4.9ms preprocess, 162.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 185.0ms
# Speed: 8.6ms preprocess, 185.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 178.3ms
# Speed: 4.1ms preprocess, 178.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.3ms
# Speed: 12.1ms preprocess, 158.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 168.7ms
# Speed: 8.6ms preprocess, 168.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 170.5ms
# Speed: 4.8ms preprocess, 170.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 172.9ms
# Speed: 3.2ms preprocess, 172.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.3ms
# Speed: 3.5ms preprocess, 158.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 178.5ms
# Speed: 3.3ms preprocess, 178.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 153.9ms
# Speed: 8.9ms preprocess, 153.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 167.5ms
# Speed: 4.3ms preprocess, 167.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 302.3ms
# Speed: 4.8ms preprocess, 302.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 153.2ms
# Speed: 5.1ms preprocess, 153.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 150.5ms
# Speed: 6.5ms preprocess, 150.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 154.0ms
# Speed: 6.4ms preprocess, 154.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 156.8ms
# Speed: 4.9ms preprocess, 156.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 153.3ms
# Speed: 6.4ms preprocess, 153.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 147.1ms
# Speed: 5.9ms preprocess, 147.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 150.8ms
# Speed: 6.2ms preprocess, 150.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.0ms
# Speed: 4.7ms preprocess, 158.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.0ms
# Speed: 6.7ms preprocess, 158.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 154.9ms
# Speed: 6.2ms preprocess, 154.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 148.8ms
# Speed: 3.8ms preprocess, 148.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 151.7ms
# Speed: 5.1ms preprocess, 151.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 151.9ms
# Speed: 6.4ms preprocess, 151.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.1ms
# Speed: 3.6ms preprocess, 165.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 161.2ms
# Speed: 4.6ms preprocess, 161.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.7ms
# Speed: 7.1ms preprocess, 159.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 148.1ms
# Speed: 6.5ms preprocess, 148.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 160.8ms
# Speed: 6.2ms preprocess, 160.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.4ms
# Speed: 4.5ms preprocess, 165.4ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 185.9ms
# Speed: 6.2ms preprocess, 185.9ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 173.8ms
# Speed: 5.6ms preprocess, 173.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.8ms
# Speed: 5.8ms preprocess, 167.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 158.6ms
# Speed: 4.0ms preprocess, 158.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 291.7ms
# Speed: 4.9ms preprocess, 291.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 195.5ms
# Speed: 3.5ms preprocess, 195.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.9ms
# Speed: 10.7ms preprocess, 158.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 163.2ms
# Speed: 8.1ms preprocess, 163.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 147.4ms
# Speed: 3.3ms preprocess, 147.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 178.9ms
# Speed: 4.1ms preprocess, 178.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 156.8ms
# Speed: 6.8ms preprocess, 156.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 145.6ms
# Speed: 4.1ms preprocess, 145.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 153.5ms
# Speed: 6.7ms preprocess, 153.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 151.4ms
# Speed: 4.7ms preprocess, 151.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 161.6ms
# Speed: 9.0ms preprocess, 161.6ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 177.9ms
# Speed: 5.7ms preprocess, 177.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.2ms
# Speed: 4.0ms preprocess, 165.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 168.3ms
# Speed: 8.8ms preprocess, 168.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 174.8ms
# Speed: 6.4ms preprocess, 174.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.9ms
# Speed: 4.5ms preprocess, 148.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.0ms
# Speed: 6.4ms preprocess, 170.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.8ms
# Speed: 5.5ms preprocess, 171.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.2ms
# Speed: 7.9ms preprocess, 171.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 195.7ms
# Speed: 3.5ms preprocess, 195.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 156.8ms
# Speed: 3.4ms preprocess, 156.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 151.1ms
# Speed: 4.7ms preprocess, 151.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 135.7ms
# Speed: 7.1ms preprocess, 135.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 179.3ms
# Speed: 5.8ms preprocess, 179.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.7ms
# Speed: 10.9ms preprocess, 154.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 352.5ms
# Speed: 4.8ms preprocess, 352.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 152.3ms
# Speed: 16.7ms preprocess, 152.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 160.0ms
# Speed: 3.6ms preprocess, 160.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 168.9ms
# Speed: 3.9ms preprocess, 168.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 161.4ms
# Speed: 4.9ms preprocess, 161.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 167.1ms
# Speed: 3.8ms preprocess, 167.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 171.7ms
# Speed: 3.7ms preprocess, 171.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 178.1ms
# Speed: 6.1ms preprocess, 178.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 179.9ms
# Speed: 9.8ms preprocess, 179.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 167.3ms
# Speed: 4.1ms preprocess, 167.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 171.9ms
# Speed: 6.1ms preprocess, 171.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 161.1ms
# Speed: 3.6ms preprocess, 161.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 175.6ms
# Speed: 4.8ms preprocess, 175.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 171.1ms
# Speed: 11.0ms preprocess, 171.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 208.8ms
# Speed: 6.0ms preprocess, 208.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 185.6ms
# Speed: 9.2ms preprocess, 185.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 183.5ms
# Speed: 3.7ms preprocess, 183.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 174.2ms
# Speed: 3.6ms preprocess, 174.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 181.1ms
# Speed: 3.7ms preprocess, 181.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 312.9ms
# Speed: 4.0ms preprocess, 312.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 177.5ms
# Speed: 5.2ms preprocess, 177.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 399.4ms
# Speed: 9.7ms preprocess, 399.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 169.0ms
# Speed: 7.7ms preprocess, 169.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 185.5ms
# Speed: 10.3ms preprocess, 185.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 177.4ms
# Speed: 4.2ms preprocess, 177.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 159.2ms
# Speed: 6.4ms preprocess, 159.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 170.9ms
# Speed: 5.5ms preprocess, 170.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 198.0ms
# Speed: 4.7ms preprocess, 198.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 166.3ms
# Speed: 5.6ms preprocess, 166.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 183.3ms
# Speed: 3.7ms preprocess, 183.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 261.0ms
# Speed: 4.7ms preprocess, 261.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 191.8ms
# Speed: 3.1ms preprocess, 191.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 161.2ms
# Speed: 5.8ms preprocess, 161.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 166.5ms
# Speed: 5.9ms preprocess, 166.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 176.3ms
# Speed: 3.7ms preprocess, 176.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 265.7ms
# Speed: 7.3ms preprocess, 265.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 158.5ms
# Speed: 4.4ms preprocess, 158.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.5ms
# Speed: 4.1ms preprocess, 155.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 180.7ms
# Speed: 3.8ms preprocess, 180.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 179.6ms
# Speed: 4.2ms preprocess, 179.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 201.9ms
# Speed: 8.4ms preprocess, 201.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 288.7ms
# Speed: 4.8ms preprocess, 288.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 178.8ms
# Speed: 6.7ms preprocess, 178.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 171.5ms
# Speed: 3.7ms preprocess, 171.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.1ms
# Speed: 15.3ms preprocess, 153.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.4ms
# Speed: 4.3ms preprocess, 151.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.6ms
# Speed: 7.1ms preprocess, 153.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.5ms
# Speed: 8.5ms preprocess, 148.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 156.0ms
# Speed: 9.6ms preprocess, 156.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 156.0ms
# Speed: 6.1ms preprocess, 156.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 170.2ms
# Speed: 6.3ms preprocess, 170.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.6ms
# Speed: 3.7ms preprocess, 155.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.9ms
# Speed: 6.3ms preprocess, 155.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.2ms
# Speed: 6.3ms preprocess, 154.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 156.9ms
# Speed: 6.8ms preprocess, 156.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 166.9ms
# Speed: 6.0ms preprocess, 166.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 225.4ms
# Speed: 4.2ms preprocess, 225.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 236.7ms
# Speed: 11.9ms preprocess, 236.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 169.6ms
# Speed: 5.1ms preprocess, 169.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.8ms
# Speed: 4.1ms preprocess, 157.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 170.8ms
# Speed: 5.2ms preprocess, 170.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.3ms
# Speed: 7.1ms preprocess, 149.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.9ms
# Speed: 3.7ms preprocess, 147.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 145.4ms
# Speed: 4.1ms preprocess, 145.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.2ms
# Speed: 7.1ms preprocess, 147.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 275.2ms
# Speed: 6.0ms preprocess, 275.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.3ms
# Speed: 5.3ms preprocess, 153.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 179.8ms
# Speed: 5.5ms preprocess, 179.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.1ms
# Speed: 5.6ms preprocess, 151.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.3ms
# Speed: 6.7ms preprocess, 153.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.1ms
# Speed: 6.2ms preprocess, 147.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.5ms
# Speed: 16.5ms preprocess, 148.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.2ms
# Speed: 8.2ms preprocess, 147.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 145.4ms
# Speed: 6.7ms preprocess, 145.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 152.6ms
# Speed: 4.1ms preprocess, 152.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.7ms
# Speed: 8.2ms preprocess, 154.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 164.2ms
# Speed: 4.5ms preprocess, 164.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.8ms
# Speed: 5.4ms preprocess, 157.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 163.1ms
# Speed: 4.0ms preprocess, 163.1ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 150.9ms
# Speed: 6.0ms preprocess, 150.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 156.5ms
# Speed: 6.7ms preprocess, 156.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.7ms
# Speed: 5.3ms preprocess, 146.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 164.0ms
# Speed: 6.4ms preprocess, 164.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.1ms
# Speed: 7.4ms preprocess, 157.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.0ms
# Speed: 7.0ms preprocess, 147.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.5ms
# Speed: 6.2ms preprocess, 153.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 164.3ms
# Speed: 4.6ms preprocess, 164.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 150.6ms
# Speed: 4.4ms preprocess, 150.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.9ms
# Speed: 6.2ms preprocess, 153.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 297.7ms
# Speed: 3.0ms preprocess, 297.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.5ms
# Speed: 4.5ms preprocess, 158.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 149.1ms
# Speed: 9.3ms preprocess, 149.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 156.9ms
# Speed: 5.2ms preprocess, 156.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 161.9ms
# Speed: 6.1ms preprocess, 161.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 148.8ms
# Speed: 7.3ms preprocess, 148.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 150.9ms
# Speed: 4.3ms preprocess, 150.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.5ms
# Speed: 4.3ms preprocess, 159.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 151.4ms
# Speed: 4.0ms preprocess, 151.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 168.2ms
# Speed: 5.3ms preprocess, 168.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 153.9ms
# Speed: 5.8ms preprocess, 153.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 153.5ms
# Speed: 4.8ms preprocess, 153.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 154.2ms
# Speed: 4.7ms preprocess, 154.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 164.6ms
# Speed: 8.1ms preprocess, 164.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 168.3ms
# Speed: 4.7ms preprocess, 168.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 164.8ms
# Speed: 4.7ms preprocess, 164.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 155.1ms
# Speed: 4.0ms preprocess, 155.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 151.7ms
# Speed: 4.7ms preprocess, 151.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 151.3ms
# Speed: 4.4ms preprocess, 151.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 154.6ms
# Speed: 5.1ms preprocess, 154.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 153.8ms
# Speed: 5.8ms preprocess, 153.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 152.5ms
# ...
#
# 0: 384x640 (no detections), 146.8ms
# Speed: 5.9ms preprocess, 146.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.3ms
# Speed: 6.2ms preprocess, 149.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 152.5ms
# Speed: 3.2ms preprocess, 152.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.9ms
# Speed: 5.3ms preprocess, 149.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.0ms
# Speed: 5.5ms preprocess, 151.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 283.3ms
# Speed: 3.4ms preprocess, 283.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.2ms
# Speed: 8.6ms preprocess, 149.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.4ms
# Speed: 4.4ms preprocess, 146.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 161.5ms
# Speed: 8.0ms preprocess, 161.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 180.3ms
# Speed: 6.4ms preprocess, 180.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.8ms
# Speed: 5.9ms preprocess, 151.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.4ms
# Speed: 4.4ms preprocess, 153.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.2ms
# Speed: 8.5ms preprocess, 147.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 152.2ms
# Speed: 7.0ms preprocess, 152.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 169.5ms
# Speed: 5.0ms preprocess, 169.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.7ms
# Speed: 4.4ms preprocess, 148.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.5ms
# Speed: 6.3ms preprocess, 149.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.5ms
# Speed: 5.9ms preprocess, 147.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.7ms
# Speed: 4.0ms preprocess, 151.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.5ms
# Speed: 6.8ms preprocess, 147.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 165.6ms
# Speed: 4.7ms preprocess, 165.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.8ms
# Speed: 5.0ms preprocess, 149.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 152.3ms
# Speed: 4.8ms preprocess, 152.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.9ms
# Speed: 6.7ms preprocess, 154.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.7ms
# Speed: 5.1ms preprocess, 155.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.1ms
# Speed: 5.6ms preprocess, 157.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 145.0ms
# Speed: 6.6ms preprocess, 145.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.3ms
# Speed: 4.2ms preprocess, 148.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 150.2ms
# Speed: 6.5ms preprocess, 150.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 287.0ms
# Speed: 6.4ms preprocess, 287.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.0ms
# Speed: 5.5ms preprocess, 147.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 152.6ms
# Speed: 6.8ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.8ms
# Speed: 5.2ms preprocess, 155.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 150.1ms
# Speed: 7.9ms preprocess, 150.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.3ms
# Speed: 5.2ms preprocess, 149.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.5ms
# Speed: 4.7ms preprocess, 153.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 145.2ms
# Speed: 6.7ms preprocess, 145.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 167.1ms
# Speed: 6.9ms preprocess, 167.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.2ms
# Speed: 6.4ms preprocess, 146.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.1ms
# Speed: 5.0ms preprocess, 151.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.6ms
# Speed: 6.2ms preprocess, 148.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.0ms
# Speed: 5.6ms preprocess, 148.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 158.8ms
# Speed: 6.3ms preprocess, 158.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.1ms
# Speed: 6.6ms preprocess, 149.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 145.2ms
# Speed: 4.8ms preprocess, 145.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.4ms
# Speed: 5.1ms preprocess, 151.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 148.1ms
# Speed: 5.0ms preprocess, 148.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 153.9ms
# Speed: 5.8ms preprocess, 153.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 155.1ms
# Speed: 6.7ms preprocess, 155.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 149.3ms
# Speed: 5.5ms preprocess, 149.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 149.9ms
# Speed: 4.0ms preprocess, 149.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 149.2ms
# Speed: 7.1ms preprocess, 149.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 287.6ms
# Speed: 8.3ms preprocess, 287.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 162.0ms
# Speed: 5.9ms preprocess, 162.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 155.8ms
# Speed: 5.3ms preprocess, 155.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 163.3ms
# Speed: 5.9ms preprocess, 163.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 149.3ms
# Speed: 4.4ms preprocess, 149.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 156.7ms
# Speed: 4.4ms preprocess, 156.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 201.4ms
# Speed: 5.8ms preprocess, 201.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 206.1ms
# Speed: 7.8ms preprocess, 206.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 145.7ms
# Speed: 5.3ms preprocess, 145.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 150.1ms
# Speed: 5.0ms preprocess, 150.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 150.6ms
# Speed: 6.2ms preprocess, 150.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 164.6ms
# Speed: 7.0ms preprocess, 164.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 152.5ms
# Speed: 5.8ms preprocess, 152.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 151.2ms
# Speed: 6.3ms preprocess, 151.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 147.9ms
# Speed: 5.3ms preprocess, 147.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 154.6ms
# Speed: 3.8ms preprocess, 154.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 143.1ms
# Speed: 8.7ms preprocess, 143.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 146.9ms
# Speed: 5.3ms preprocess, 146.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.7ms
# Speed: 5.5ms preprocess, 154.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 153.2ms
# Speed: 4.1ms preprocess, 153.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 164.5ms
# Speed: 6.3ms preprocess, 164.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 152.0ms
# Speed: 6.1ms preprocess, 152.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 163.8ms
# Speed: 4.4ms preprocess, 163.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 173.7ms
# Speed: 6.5ms preprocess, 173.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 276.2ms
# Speed: 5.9ms preprocess, 276.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 150.1ms
# Speed: 4.5ms preprocess, 150.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 160.3ms
# Speed: 5.5ms preprocess, 160.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 151.6ms
# Speed: 10.9ms preprocess, 151.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.4ms
# Speed: 4.7ms preprocess, 155.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 149.1ms
# Speed: 6.3ms preprocess, 149.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.3ms
# Speed: 3.2ms preprocess, 148.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.9ms
# Speed: 5.1ms preprocess, 151.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 150.5ms
# Speed: 7.4ms preprocess, 150.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.9ms
# Speed: 5.8ms preprocess, 153.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.3ms
# Speed: 3.8ms preprocess, 149.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.9ms
# Speed: 5.3ms preprocess, 149.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.5ms
# Speed: 6.0ms preprocess, 146.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.4ms
# Speed: 6.6ms preprocess, 149.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.2ms
# Speed: 5.8ms preprocess, 146.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 144.4ms
# Speed: 5.4ms preprocess, 144.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.5ms
# Speed: 5.8ms preprocess, 151.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.8ms
# Speed: 4.6ms preprocess, 146.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.5ms
# Speed: 6.2ms preprocess, 149.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 168.2ms
# Speed: 5.2ms preprocess, 168.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 171.9ms
# Speed: 5.7ms preprocess, 171.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 152.9ms
# Speed: 3.3ms preprocess, 152.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.9ms
# Speed: 5.8ms preprocess, 146.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 143.4ms
# Speed: 4.7ms preprocess, 143.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 278.2ms
# Speed: 7.7ms preprocess, 278.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 150.6ms
# Speed: 6.3ms preprocess, 150.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.3ms
# Speed: 5.6ms preprocess, 149.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 150.9ms
# Speed: 6.3ms preprocess, 150.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.6ms
# Speed: 3.0ms preprocess, 146.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.1ms
# Speed: 6.4ms preprocess, 148.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.4ms
# Speed: 5.9ms preprocess, 146.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 166.9ms
# Speed: 5.9ms preprocess, 166.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.5ms
# Speed: 5.8ms preprocess, 154.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.0ms
# Speed: 7.0ms preprocess, 153.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 159.0ms
# Speed: 5.3ms preprocess, 159.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.7ms
# Speed: 7.9ms preprocess, 151.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 150.7ms
# Speed: 4.8ms preprocess, 150.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.4ms
# Speed: 8.1ms preprocess, 148.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.2ms
# Speed: 6.2ms preprocess, 154.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 169.1ms
# Speed: 5.1ms preprocess, 169.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.4ms
# Speed: 5.6ms preprocess, 149.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.3ms
# Speed: 10.6ms preprocess, 146.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.9ms
# Speed: 5.6ms preprocess, 157.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Video processed and saved to: Save Images & Videos/output_video.avi

# %%
import cv2

# %%
# Path to your image
imagen_path = "Image Useful\\pose_landmarks_index.png"  # <-- change this to your image

# Load image
imagen = cv2.imread(imagen_path)

# Function called on mouse click
def mostrar_coordenadas(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        print(f"Coordinates: x={x}, y={y}")
        # Draw a circle at the click position
        cv2.circle(imagen, (x, y), 5, (0, 255, 0), -1)
        cv2.putText(imagen, f"({x},{y})", (x+10, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,255,0), 1)
        cv2.imshow("Interactive Image", imagen)

# Show the image and start listening for mouse events
cv2.imshow("Interactive Image", imagen)
cv2.setMouseCallback("Interactive Image", mostrar_coordenadas)

# Wait until a key is pressed
cv2.waitKey(0)
cv2.destroyAllWindows()
